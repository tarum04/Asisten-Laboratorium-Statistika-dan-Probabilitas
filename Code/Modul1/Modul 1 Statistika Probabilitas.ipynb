# %%
import pandas as pd
df = pd.read_csv("C:/Users/ASUS/Desktop/PRAK PROB STATIS/BahanPraktikum_Statistika.csv",sep=';')
df
# Out:
#       Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0    Risma      W      2022           157               120          Bekasi
# 1    Putri      W      2022           155                55         Jakarta
# 2   Aisyah      W      2022           155                60       Tangerang
# 3    Rhena      W      2022           155                70       Tangerang
# 4   Chaesa      W      2022           160                60           Depok
# 5    Sonya      W      2022           160               140         Jakarta
# 6    Vania      W      2022           163                40         Jakarta
# 7    Aulia      W      2022           160                30          Bekasi
# 8    Andri      P      2022           161               120          Bekasi
# 9    Rabih      P      2022           175               120         Jakarta
# 10    Isky      P      2022           171                30         Jakarta
# ...

# %%
df = pd.read_excel("C:/Users/ASUS/Desktop/PRAK PROB STATIS/tarum.xlsx")
df
# Out:
#       Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0    Risma      W      2022           157               120          Bekasi
# 1    Putri      W      2022           155                55         Jakarta
# 2   Aisyah      W      2022           155                60       Tangerang
# 3    Rhena      W      2022           155                70       Tangerang
# 4   Chaesa      W      2022           160                60           Depok
# 5    Sonya      W      2022           160               140         Jakarta
# 6    Vania      W      2022           163                40         Jakarta
# 7    Aulia      W      2022           160                30          Bekasi
# 8    Andri      P      2022           161               120          Bekasi
# 9    Rabih      P      2022           175               120         Jakarta
# 10    Isky      P      2022           171                30         Jakarta
# ...

# %%
df =pd.read_clipboard()

# %%
df
# Out:
#       Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0    Risma      W      2022           157               120          Bekasi
# 1    Putri      W      2022           155                55         Jakarta
# 2   Aisyah      W      2022           155                60       Tangerang
# 3    Rhena      W      2022           155                70       Tangerang
# 4   Chaesa      W      2022           160                60           Depok
# 5    Sonya      W      2022           160               140         Jakarta
# 6    Vania      W      2022           163                40         Jakarta
# 7    Aulia      W      2022           160                30          Bekasi
# 8    Andri      P      2022           161               120          Bekasi
# 9    Rabih      P      2022           175               120         Jakarta
# 10    Isky      P      2022           171                30         Jakarta
# ...

# %%
#menghitung rata-rata tinggi
rata_tinggi = df['Tinggi Badan'].mean()
rata_tinggi
# Out:
# 164.85

# %%
print(df.dtypes)
# Out:
# Nama                object
# Gender              object
# Angkatan             int64
# Tinggi Badan         int64
# Waktu Perjalanan     int64
# Wilayah Tinggal     object
# dtype: object

# %%
#mengubah tipe data kolom 'Angkatan' menjadi string 
df['Angkatan'] = df['Angkatan'].astype(str)

# %%
print(df.dtypes)
# Out:
# Nama                object
# Gender              object
# Angkatan            object
# Tinggi Badan         int64
# Waktu Perjalanan     int64
# Wilayah Tinggal     object
# dtype: object
